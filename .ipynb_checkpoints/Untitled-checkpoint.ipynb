# %%
import numpy as np
import warnings
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import linear_kernel
from sklearn.metrics import accuracy_score,f1_score, roc_auc_score, precision_score, recall_score, make_scorer
from sklearn.preprocessing import MinMaxScaler, StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, ExtraTreesClassifier, BaggingClassifier, VotingClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedShuffleSplit, RandomizedSearchCV
import lightgbm as lgb
pd.options.display.max_columns = 500
warnings.filterwarnings(action='ignore')

# %%
train=pd.read_csv(r'C:\Users\Rahul\Desktop\Machinehack-Message-polarity-prediction\Train.csv')
test=pd.read_csv(r'C:\Users\Rahul\Desktop\Machinehack-Message-polarity-prediction\Test.csv')

# %%
train.head()
# Out:
#    Freq_Of_Word_1  Freq_Of_Word_2  Freq_Of_Word_3  Freq_Of_Word_4  \
# 0       -0.351864        2.620660        1.253645       -0.039223
# 1       -0.351864       -0.318036       -0.561952       -0.039223
# 2       -0.351864       -0.318036       -0.561952       -0.039223
# 3        1.210190        2.682528        1.291868       -0.039223
# 4       -0.351864       -0.318036       -0.561952       -0.039223
#
#    Freq_Of_Word_5  Freq_Of_Word_6  Freq_Of_Word_7  Freq_Of_Word_8  \
# 0       -0.465210       -0.353977       -0.304257       -0.240708
# 1       -0.465210       -0.353977       -0.304257        3.837751
# 2       -0.465210       -0.353977       -0.304257       -0.240708
# 3        0.221744       -0.353977       -0.304257        0.859101
# 4       -0.465210       -0.353977       -0.304257       -0.240708
#
#    Freq_Of_Word_9  Freq_Of_Word_10  Freq_Of_Word_11  Freq_Of_Word_12  \
# 0       -0.318797        -0.352968        -0.320591        -0.635215
# 1       -0.318797        -0.352968        -0.320591        -0.635215
# 2       -0.318797        -0.352968        -0.320591        -0.635215
# 3       -0.318797         2.374782        -0.320591         2.030243
# 4       -0.318797        -0.352968        -0.320591        -0.635215
#
#    Freq_Of_Word_13  Freq_Of_Word_14  Freq_Of_Word_15  Freq_Of_Word_16  \
# 0        -0.307555        -0.184379        -0.189867        -0.333610
# 1        -0.307555        -0.184379        -0.189867        -0.333610
# 2        -0.307555        -0.184379        -0.189867        -0.333610
# 3        -0.307555         1.287387        -0.189867         0.289792
# 4        -0.307555        -0.184379        -0.189867        -0.333610
#
#    Freq_Of_Word_17  Freq_Of_Word_18  Freq_Of_Word_19  Freq_Of_Word_20  \
# 0        -0.321557        -0.362461        -0.707520         1.065873
# 1        -0.321557        -0.362461        -0.973161        -0.191111
# 2        -0.321557        -0.362461        -0.973161        -0.191111
# 3        -0.321557        -0.362461         0.128969        -0.191111
# 4        -0.321557        -0.362461        -0.973161        -0.191111
#
#    Freq_Of_Word_21  Freq_Of_Word_22  Freq_Of_Word_23  Freq_Of_Word_24  \
# 0         0.953319        -0.132948        -0.291683         0.764765
# 1        -0.707575        -0.132948        -0.291683        -0.197881
# 2        -0.707575        -0.132948        -0.291683        -0.197881
# 3         3.977893        -0.132948        -0.291683        -0.197881
# 4        -0.707575        -0.132948        -0.291683        -0.197881
#
# count       527.000000       527.000000            527.000000
# mean         -0.014241        -0.051894              0.029887
# std           0.874084         0.771676              1.241018
# min          -0.151911        -0.453742             -0.107383
# 25%          -0.151911        -0.453742             -0.107383
# 50%          -0.151911        -0.258182             -0.081172
# 75%          -0.151911         0.070299             -0.054961
# max          13.763001        12.596883             26.627430
#
#        LengthOFFirstParagraph  StylizedLetters
# count              527.000000       527.000000
# mean                 0.010378        -0.015275
# std                  0.632055         0.697853
# min                 -0.219003        -0.427682
# 25%                 -0.191555        -0.368707
# 50%                 -0.156265        -0.274627
# 75%                 -0.038632         0.004103
# max                  7.783974         4.163982

# %%
train.drop_duplicates(inplace=True)
train.reset_index(inplace = True, drop = True)

# %%
df = train.append(test, sort = False)

# %%
df.drop(columns = 'IsGoodNews').duplicated().value_counts()
# Out:
# False    1464
# True        6
# dtype: int64

# %%
dupp = df[df.drop(columns = 'IsGoodNews').duplicated()].index[5:]

# %%
df.reset_index(drop = True, inplace = True)

# %%
train.shape, test.shape
# Out:
# ((943, 54), (527, 53))

# %%
import seaborn as sns
sns.countplot(train.IsGoodNews)

# %% [markdown]
# # ANALYSIS EDA

# %%
for c in df.columns:
    print(f'Distinct values: {c}   {df[c].nunique()}')
# Out:
# Distinct values: Freq_Of_Word_1   102
# Distinct values: Freq_Of_Word_2   115
# Distinct values: Freq_Of_Word_3   169
# Distinct values: Freq_Of_Word_4   10
# Distinct values: Freq_Of_Word_5   184
# Distinct values: Freq_Of_Word_6   98
# Distinct values: Freq_Of_Word_7   127
# Distinct values: Freq_Of_Word_8   105
# Distinct values: Freq_Of_Word_9   100
# Distinct values: Freq_Of_Word_10   174
# Distinct values: Freq_Of_Word_11   82
# Distinct values: Freq_Of_Word_12   241
# Distinct values: Freq_Of_Word_13   113
# Distinct values: Freq_Of_Word_14   69
# Distinct values: Freq_Of_Word_15   63
# Distinct values: Freq_Of_Word_16   169
# Distinct values: Freq_Of_Word_17   132
# Distinct values: Freq_Of_Word_18   161
# Distinct values: Freq_Of_Word_19   423
# Distinct values: Freq_Of_Word_20   78
# Distinct values: Freq_Of_Word_21   302
# Distinct values: Freq_Of_Word_22   37
# Distinct values: Freq_Of_Word_23   115
# Distinct values: Freq_Of_Word_24   93
# Distinct values: Freq_Of_Word_25   223
# Distinct values: Freq_Of_Word_26   167
# Distinct values: Freq_Of_Word_27   153
# Distinct values: Freq_Of_Word_28   105
# Distinct values: Freq_Of_Word_29   96
# Distinct values: Freq_Of_Word_30   99
# Distinct values: Freq_Of_Word_31   70
# Distinct values: Freq_Of_Word_32   59
# Distinct values: Freq_Of_Word_33   93
# Distinct values: Freq_Of_Word_34   60
# Distinct values: Freq_Of_Word_35   106
# Distinct values: Freq_Of_Word_36   109
# Distinct values: Freq_Of_Word_37   133
# Distinct values: Freq_Of_Word_38   25
# Distinct values: Freq_Of_Word_39   93
# Distinct values: Freq_Of_Word_40   79
# Distinct values: Freq_Of_Word_41   46
# Distinct values: Freq_Of_Word_42   88
# Distinct values: Freq_Of_Word_43   76
# Distinct values: Freq_Of_Word_44   78
# Distinct values: Freq_Of_Word_45   185
# Distinct values: Freq_Of_Word_46   120
# Distinct values: Freq_Of_Word_47   18
# Distinct values: Freq_Of_Word_48   54
# Distinct values: Freq_Of_Word_49   174
# Distinct values: Freq_Of_Word_50   425
# Distinct values: TotalEmojiCharacters   37
# Distinct values: LengthOFFirstParagraph   180
# Distinct values: StylizedLetters   550
# Distinct values: IsGoodNews   2

# %%
import seaborn as sns
plt.subplots(6,3, figsize = (15,25))
for i, c in enumerate(df.columns[0:18]):
    plt.subplot(6,3,i+1)
    sns.boxplot(df.IsGoodNews, df[c])

# %%
import seaborn as sns
plt.subplots(6,3, figsize = (15,25))
for i, c in enumerate(df.columns[18:36]):
    plt.subplot(6,3,i+1)
    sns.boxplot(df.IsGoodNews, df[c])

# %%
import seaborn as sns
plt.subplots(6,3, figsize = (15,25))
for i, c in enumerate(df.columns[36:53]):
    plt.subplot(6,3,i+1)
    sns.boxplot(df.IsGoodNews, df[c])

# %%
df.columns
# Out:
# Index(['Freq_Of_Word_1', 'Freq_Of_Word_2', 'Freq_Of_Word_3', 'Freq_Of_Word_4',
#        'Freq_Of_Word_5', 'Freq_Of_Word_6', 'Freq_Of_Word_7', 'Freq_Of_Word_8',
#        'Freq_Of_Word_9', 'Freq_Of_Word_10', 'Freq_Of_Word_11',
#        'Freq_Of_Word_12', 'Freq_Of_Word_13', 'Freq_Of_Word_14',
#        'Freq_Of_Word_15', 'Freq_Of_Word_16', 'Freq_Of_Word_17',
#        'Freq_Of_Word_18', 'Freq_Of_Word_19', 'Freq_Of_Word_20',
#        'Freq_Of_Word_21', 'Freq_Of_Word_22', 'Freq_Of_Word_23',
#        'Freq_Of_Word_24', 'Freq_Of_Word_25', 'Freq_Of_Word_26',
#        'Freq_Of_Word_27', 'Freq_Of_Word_28', 'Freq_Of_Word_29',
#        'Freq_Of_Word_30', 'Freq_Of_Word_31', 'Freq_Of_Word_32',
#        'Freq_Of_Word_33', 'Freq_Of_Word_34', 'Freq_Of_Word_35',
#        'Freq_Of_Word_36', 'Freq_Of_Word_37', 'Freq_Of_Word_38',
#        'Freq_Of_Word_39', 'Freq_Of_Word_40', 'Freq_Of_Word_41',
#        'Freq_Of_Word_42', 'Freq_Of_Word_43', 'Freq_Of_Word_44',
#        'Freq_Of_Word_45', 'Freq_Of_Word_46', 'Freq_Of_Word_47',
#        'Freq_Of_Word_48', 'Freq_Of_Word_49', 'Freq_Of_Word_50',
#        'TotalEmojiCharacters', 'LengthOFFirstParagraph', 'StylizedLetters',
#        'IsGoodNews'],
#       dtype='object')

# %%
#df.drop_duplicates(inplace=True)
#df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    Freq_Of_Word_1  Freq_Of_Word_2  Freq_Of_Word_3  Freq_Of_Word_4  \
# 0       -0.351864        2.620660        1.253645       -0.039223
# 1       -0.351864       -0.318036       -0.561952       -0.039223
# 2       -0.351864       -0.318036       -0.561952       -0.039223
# 3        -0.183048        -0.152367        -0.236402        -0.244919
# 4        -0.183048        -0.152367        -0.236402        -0.244919
#
#    Freq_Of_Word_37  Freq_Of_Word_38  Freq_Of_Word_39  Freq_Of_Word_40  \
# 0        -0.329374        -0.055522        -0.181398        -0.187171
# 1         3.675591        -0.055522        -0.181398        -0.187171
# 2        -0.329374        -0.055522        -0.181398        -0.187171
# 3        -0.329374        -0.055522        -0.181398        -0.187171
# 4        -0.329374        -0.055522        -0.181398        -0.187171
#
#    Freq_Of_Word_41  Freq_Of_Word_42  Freq_Of_Word_43  Freq_Of_Word_44  \
# 0        -0.133876        -0.168998        -0.208657        -0.120401
# 1        -0.133876        -0.168998        15.211013        -0.120401
# 2        -0.133876        -0.168998        -0.208657        -0.120401
# 3        -0.133876        -0.168998        -0.208657        -0.120401
# 4        -0.133876        -0.168998        -0.208657        -0.120401
#
#    Freq_Of_Word_45  Freq_Of_Word_46  Freq_Of_Word_47  Freq_Of_Word_48  \
# 0        -0.323019        -0.205212        -0.079531        -0.118688
# 1        -0.323019        -0.205212        -0.079531        -0.118688
# 2        -0.323019        -0.205212        -0.079531        -0.118688
# 3        -0.323019        -0.205212        -0.079531        -0.118688
# 4        -0.323019        -0.205212        -0.079531        -0.118688
#
#    Freq_Of_Word_49  Freq_Of_Word_50  TotalEmojiCharacters  \
# 0         0.079303         0.157385             -0.028751
# 1        -0.151911        -0.453742             -0.107383
# 2        -0.151911        -0.453742             -0.107383
# 3        -0.151911         0.340723              1.334201
# 4        -0.151911         0.930461             -0.028751
#
#    LengthOFFirstParagraph  StylizedLetters  IsGoodNews
# 0               -0.046474         0.222453         1.0
# 1               -0.195476        -0.408024         0.0
# 2               -0.187634        -0.392578         0.0
# 3                2.270899         0.602985         1.0
# 4               -0.113133        -0.128592         0.0

# %%
df.drop(columns = ['Freq_Of_Word_4'], inplace = True)

# %%
df.columns
# Out:
# Index(['Freq_Of_Word_1', 'Freq_Of_Word_2', 'Freq_Of_Word_3', 'Freq_Of_Word_5',
#        'Freq_Of_Word_6', 'Freq_Of_Word_7', 'Freq_Of_Word_8', 'Freq_Of_Word_9',
#        'Freq_Of_Word_10', 'Freq_Of_Word_11', 'Freq_Of_Word_12',
#        'Freq_Of_Word_13', 'Freq_Of_Word_14', 'Freq_Of_Word_15',
#        'Freq_Of_Word_16', 'Freq_Of_Word_17', 'Freq_Of_Word_18',
#        'Freq_Of_Word_19', 'Freq_Of_Word_20', 'Freq_Of_Word_21',
#        'Freq_Of_Word_22', 'Freq_Of_Word_23', 'Freq_Of_Word_24',
#        'Freq_Of_Word_25', 'Freq_Of_Word_26', 'Freq_Of_Word_27',
#        'Freq_Of_Word_28', 'Freq_Of_Word_29', 'Freq_Of_Word_30',
#        'Freq_Of_Word_31', 'Freq_Of_Word_32', 'Freq_Of_Word_33',
#        'Freq_Of_Word_34', 'Freq_Of_Word_35', 'Freq_Of_Word_36',
#        'Freq_Of_Word_37', 'Freq_Of_Word_38', 'Freq_Of_Word_39',
#        'Freq_Of_Word_40', 'Freq_Of_Word_41', 'Freq_Of_Word_42',
#        'Freq_Of_Word_43', 'Freq_Of_Word_44', 'Freq_Of_Word_45',
#        'Freq_Of_Word_46', 'Freq_Of_Word_47', 'Freq_Of_Word_48',
#        'Freq_Of_Word_49', 'Freq_Of_Word_50', 'TotalEmojiCharacters',
#        'LengthOFFirstParagraph', 'StylizedLetters', 'IsGoodNews'],
#       dtype='object')

# %%
# %%time
cosine = []
ind = df.index
for r in ind:
    df[str(r)] = linear_kernel(df.iloc[r:r+1,:48], df.iloc[:,:48])[0]
    #cosine.append(linear_kernel(df.iloc[r:r+1,:48], df.iloc[:,:48]))
#cosine = linear_kernel(df.drop(columns = 'IsGoodNews').iloc[0:1,:],df.drop(columns = 'IsGoodNews')).flatten()
#cosine.argsort()[-5:-1]
# Out:
# Wall time: 5.7 s

# %%
df.shape
# Out:
# (1470, 1523)

# %%
df['mean'] = df.drop(columns = 'IsGoodNews').mean(axis =1)
df['median'] = df.drop(columns = 'IsGoodNews').median(axis =1)
df['sum'] = df.drop(columns = 'IsGoodNews').sum(axis =1)

df['skew'] = df.drop(columns = 'IsGoodNews').skew(axis =1)
df['kurt'] = df.drop(columns = 'IsGoodNews').kurt(axis =1)

# %%
train = (df[df.IsGoodNews.notnull()])
test = (df[df.IsGoodNews.isnull()])

test.reset_index(drop= True, inplace =True)
test.drop(columns = ['Freq_Of_Word_47','Freq_Of_Word_48','Freq_Of_Word_31','IsGoodNews'], inplace = True)

label = train.IsGoodNews
train.drop(columns = ['Freq_Of_Word_47','Freq_Of_Word_48','Freq_Of_Word_31','IsGoodNews'], inplace = True)

# %%
# %%time
from imblearn.under_sampling import TomekLinks
from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTETomek
tm = SMOTETomek(random_state=123123)
x,y = tm.fit_sample(train,label)
x = pd.DataFrame(x)

# %%
train.shape
# Out:
# (943, 1524)

# %%
x.shape, y.shape
# Out:
# ((1136, 1524), (1136,))

# %%
def splitting(m, train= train, label = label, test = test, random_state = 400, split = 3):
    a = list()
    b = list()
    sss=StratifiedShuffleSplit(random_state= random_state, test_size=0.2,  n_splits=split)
    pred_tr = pd.DataFrame(np.zeros(shape = (train.shape[0], 1)))
    pred_te = pd.DataFrame(np.zeros(shape = (test.shape[0], split)))

    for i, (tr_index, te_index) in enumerate(sss.split(train,label)):
        xtrain, xtest = train.loc[tr_index,:], train.loc[te_index,:]
        ytrain, ytest = label[tr_index], label[te_index]   
        m.fit(xtrain,ytrain)
        p = m.predict(xtest)
        pred_tr.loc[tr_index]
        pred_te.iloc[:,i] = m.predict(test)
        
        print(f"Training : {f1_score(ytrain,m.predict(xtrain))}   Testing : {f1_score(ytest,m.predict(xtest))}")        
        a.append(f1_score(ytrain,m.predict(xtrain)))
        b.append(f1_score(ytest,m.predict(xtest)))
            
    print(pd.Series(m.feature_importances_, index = train.columns).sort_values(ascending=True).plot.barh())
    print(f'\nTraining Mean: {np.mean(a)} \nTesting Mean: {np.mean(b)}')
    #print(f'\nAUC SCORE: {roc_auc_score(pred, label)}')
    #print(f'Precision: {precision_score(pred, label)}')
    #print(f'Recall: {recall_score(pred, label)}')
    #print(f'F1 Score: {f1_score(pred, label)}')
    return(pred_te)
    #return((pd.DataFrame(m.predict(test))))

# %%
#plt.figure(figsize=(15,9))
a=splitting(GradientBoostingClassifier(random_state=123),x,y,test,random_state=332348, split=3)
# Out:
# Training : 0.9988974641675854   Testing : 0.9646017699115044
# Training : 1.0   Testing : 0.956896551724138
# Training : 0.9988974641675854   Testing : 0.9191489361702128
# AxesSubplot(0.125,0.125;0.775x0.755)
#
# Training Mean: 0.9992649761117236
# Testing Mean: 0.9468824192686184

# %%
plt.figure(figsize=(15,9))
a=splitting(lgb.LGBMClassifier(random_state=88),x,y,test,random_state=99, split=5)
# Out:
# Training : 0.9988974641675854   Testing : 0.9454545454545454
# Training : 0.9988974641675854   Testing : 0.9613733905579399
# Training : 0.9988974641675854   Testing : 0.9304347826086956
# Training : 1.0   Testing : 0.9868995633187774
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-82-50980a9d85f2> in <module>
#       1 plt.figure(figsize=(15,9))
# ----> 2 a=splitting(lgb.LGBMClassifier(random_state=88),x,y,test,random_state=99, split=5)
#
# <ipython-input-80-f39d5588be80> in splitting(m, train, label, test, random_state, split)
#       9         xtrain, xtest = train.loc[tr_index,:], train.loc[te_index,:]
#      10         ytrain, ytest = label[tr_index], label[te_index]
# ---> 11         m.fit(xtrain,ytrain)
#      12         p = m.predict(xtest)
#      13         pred_tr.loc[tr_index]
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     803                                         verbose=verbose, feature_name=feature_name,
#     804                                         categorical_feature=categorical_feature,
# --> 805                                         callbacks=callbacks)
#     806         return self
#     807
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     598                               verbose_eval=verbose, feature_name=feature_name,
#     599                               categorical_feature=categorical_feature,
# --> 600                               callbacks=callbacks)
#     601
#     602         if evals_result:
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     247                                     evaluation_result_list=None))
#     248
# --> 249         booster.update(fobj=fobj)
#     250
#     251         evaluation_result_list = []
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py in update(self, train_set, fobj)
#    1974             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1975                 self.handle,
# -> 1976                 ctypes.byref(is_finished)))
#    1977             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1978             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
def f1_(pred, true):
    return(f1_score(pred,true))
f1_value = make_scorer(f1_, greater_is_better=True)

# %%
# %%time
dist={
    'learning_rate':[0.01, 1, 0.1,0.005],'max_depth':[-1],'num_leaves':[30,35,40,45,47,50,58], 
    'subsample':[0.1,0.2,0.3,0.5], 'lambda_l1':[0.3,0.4,0.5,0.6,0.8], 'lambda_l2':[0.1, 0.3,0.5,1, 1.5, 2, 3],
    'boosting_type': ['gbdt','dart','goss'], 'feature_fraction':[0.1,0.3,0.5,0.7,0.9],'bagging_fraction':[0.1,0.3,0.5,0.7,0.9]
}
random_cv=RandomizedSearchCV(lgb.LGBMClassifier(random_state=123123, n_estimators=300), dist, cv = 5, scoring=f1_value,
                             random_state = 1334)
random_cv.fit(x,y)
# Out:
# Wall time: 10.5 s

# %%
random_cv.best_score_, random_cv.best_params_
# Out:
# (0.9461980495831679,
#  {'subsample': 0.2,
#   'num_leaves': 30,
#   'max_depth': -1,
#   'learning_rate': 0.1,
#   'lambda_l2': 0.1,
#   'lambda_l1': 0.8,
#   'feature_fraction': 0.9,
#   'boosting_type': 'dart',
#   'bagging_fraction': 0.1})

# %%
random_cv.best_estimator_
# Out:
# LGBMClassifier(bagging_fraction=0.1, boosting_type='dart', class_weight=None,
#         colsample_bytree=1.0, feature_fraction=0.9,
#         importance_type='split', lambda_l1=0.8, lambda_l2=0.1,
#         learning_rate=0.1, max_depth=-1, min_child_samples=20,
#         min_child_weight=0.001, min_split_gain=0.0, n_estimators=300,
#         n_jobs=-1, num_leaves=30, objective=None, random_state=123123,
#         reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=0.2,
#         subsample_for_bin=200000, subsample_freq=0)

# %%
np.sum(a, axis= 1).value_counts()
# Out:
# 0.0    308
# 5.0    192
# 1.0     13
# 4.0     11
# 2.0      3
# dtype: int64

# %%
a = np.sum(a, axis= 1)

# %%
a = np.where(a>4,1,0)

# %%
b=splitting(AdaBoostClassifier(LogisticRegression(class_weight = 'balanced'), n_estimators = 1000),x,y,test,random_state=324123)
# Out:
# Training : 0.924778761061947   Testing : 0.923728813559322
# Training : 0.9261300992282249   Testing : 0.9184549356223176
# Training : 0.9320175438596491   Testing : 0.935064935064935
# Training : 0.9428571428571428   Testing : 0.8968609865470852
# Training : 0.9271523178807947   Testing : 0.9565217391304348
# 0.9305871729775518                0.9261262819848189

# %%
c=splitting(BaggingClassifier(LogisticRegression()),x,y,test,random_state=3645)
# Out:
# Training : 0.9330406147091109   Testing : 0.9473684210526315
# Training : 0.9493392070484582   Testing : 0.8750000000000001
# Training : 0.9372937293729372   Testing : 0.9035087719298246
# Training : 0.9354120267260578   Testing : 0.9035087719298246
# Training : 0.933920704845815   Testing : 0.9478260869565217
# 0.9378012565404757                0.9154424103737606

# %%
d=splitting(RandomForestClassifier(),x,y,test,random_state=67)
# Out:
# Training : 0.9967141292442497   Testing : 0.9298245614035088
# Training : 0.994535519125683   Testing : 0.9074074074074074
# Training : 0.9956140350877193   Testing : 0.9184549356223176
# Training : 0.9956236323851203   Testing : 0.9688888888888889
# Training : 0.9945115257958288   Testing : 0.9327354260089685
# 0.9953997683277201                0.9314622438662182

# %%
e=splitting(DecisionTreeClassifier(),x,y,test,random_state=453)
# Out:
# Training : 0.9989094874591058   Testing : 0.8991596638655464
# Training : 1.0   Testing : 0.875
# Training : 0.9989094874591058   Testing : 0.9322033898305084
# Training : 0.9989071038251366   Testing : 0.8684210526315789
# Training : 1.0   Testing : 0.8870292887029289
# 0.9993452157486697                0.8923626790061124

# %%
f=splitting(ExtraTreesClassifier(random_state=567),x,y,test,random_state=131342)
# Out:
# Training : 0.9989047097480832   Testing : 0.9181818181818183
# Training : 0.9989071038251366   Testing : 0.9519650655021834
# Training : 0.9989071038251366   Testing : 0.9310344827586208
# Training : 0.9989071038251366   Testing : 0.9469026548672567
# Training : 0.9989094874591058   Testing : 0.9224137931034483
# 0.9989071017365199                0.9340995628826654

# %%
g=splitting(SGDClassifier(),x,y,test,random_state=432)
# Out:
# Training : 0.9024110218140069   Testing : 0.8317757009345794
# Training : 0.9290465631929046   Testing : 0.9043478260869565
# Training : 0.8822857142857143   Testing : 0.8990825688073394
# Training : 0.8964732650739478   Testing : 0.8782608695652175
# Training : 0.9046610169491526   Testing : 0.8907563025210085
# 0.9029755162631451                0.8808446535830203
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)

# %%
h=splitting(LogisticRegression(class_weight = 'balanced'),x,y,test,random_state=765)
# Out:
# Training : 0.9405286343612335   Testing : 0.9264069264069263
# Training : 0.9325966850828729   Testing : 0.9527896995708155
# Training : 0.9361233480176211   Testing : 0.9385964912280702
# Training : 0.9315673289183223   Testing : 0.9523809523809523
# Training : 0.9431072210065645   Testing : 0.8949771689497716
# 0.9367846434773227                0.9330302477073072

# %%
h=splitting(VotingClassifier(estimators=[('Log',LogisticRegression(class_weight='balanced', random_state=12)),
                                         ('Extra', ExtraTreesClassifier(random_state=12)), 
                                         ('Gradient', AdaBoostClassifier(random_state=12))]), x, y, test, 
                                            random_state=113)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Training : 0.9780701754385965   Testing : 0.923076923076923
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Training : 0.9802197802197802   Testing : 0.9511111111111112
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Training : 0.9847161572052401   Testing : 0.9339207048458149
# Training : 0.9724972497249725   Testing : 0.9519650655021834
# Training : 0.9824945295404814   Testing : 0.9527896995708155
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 0.979599578425814                0.9425727008213697
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
sample=pd.read_excel(r'C:\Users\Rahul\Desktop\Machinehack-Message-polarity-prediction\Sample_Submission.xlsx')

# %%
sample.head()
# Out:
#    IsGoodNews
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
len(sample)
# Out:
# 527

# %%
sample.IsGoodNews = a.astype('int')

# %%
dupp
# Out:
# Int64Index([153, 354, 397, 421, 502], dtype='int64')

# %%
sample.loc[dupp,:]
# Out:
#      IsGoodNews
# 153           1
# 354           1
# 397           0
# 421           1
# 502           1

# %%
#sample.IsGoodNews[397] = 1

# %%
sample.IsGoodNews.value_counts()
# Out:
# 0    335
# 1    192
# Name: IsGoodNews, dtype: int64

# %%
sample.to_excel('Predicted.xlsx',index=False)
