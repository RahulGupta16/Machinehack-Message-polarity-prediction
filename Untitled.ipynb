# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score,f1_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, ExtraTreesClassifier, BaggingClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedShuffleSplit

# %%
train=pd.read_csv('D:\Machine Learning stuffs\Machinehack-Message-polarity-prediction\MessagePolarity_ParticipantsData\Train.csv')
test=pd.read_csv('D:\Machine Learning stuffs\Machinehack-Message-polarity-prediction\MessagePolarity_ParticipantsData\Test.csv')

# %%
train.head()
# Out:
#    Freq_Of_Word_1  Freq_Of_Word_2  Freq_Of_Word_3  Freq_Of_Word_4  \
# 0       -0.351864        2.620660        1.253645       -0.039223
# 1       -0.351864       -0.318036       -0.561952       -0.039223
# 2       -0.351864       -0.318036       -0.561952       -0.039223
# 3        1.210190        2.682528        1.291868       -0.039223
# 4       -0.351864       -0.318036       -0.561952       -0.039223
#
#    Freq_Of_Word_5  Freq_Of_Word_6  Freq_Of_Word_7  Freq_Of_Word_8  \
# 0       -0.465210       -0.353977       -0.304257       -0.240708
# 1       -0.465210       -0.353977       -0.304257        3.837751
# 2       -0.465210       -0.353977       -0.304257       -0.240708
# 3        0.221744       -0.353977       -0.304257        0.859101
# 4       -0.465210       -0.353977       -0.304257       -0.240708
#
#    Freq_Of_Word_9  Freq_Of_Word_10  ...  Freq_Of_Word_45  Freq_Of_Word_46  \
# 0       -0.318797        -0.352968  ...        -0.323019        -0.205212
# ...

# %%
test.head()
# Out:
#    Freq_Of_Word_1  Freq_Of_Word_2  Freq_Of_Word_3  Freq_Of_Word_4  \
# 0       -0.351864       -0.318036       -0.561952       -0.039223
# 1       -0.351864       -0.318036       -0.561952       -0.039223
# 2        0.006107       -0.318036       -0.351725       -0.039223
# 3       -0.351864       -0.318036       -0.561952       -0.039223
# 4        0.624420        0.609973       -0.561952       -0.039223
#
#    Freq_Of_Word_5  Freq_Of_Word_6  Freq_Of_Word_7  Freq_Of_Word_8  \
# 0       -0.465210       -0.353977       -0.304257       -0.240708
# 1        0.007071       -0.353977       -0.304257       -0.240708
# 2       -0.307783        0.027319       -0.304257       -0.240708
# 3       -0.465210       -0.353977        2.089042       -0.240708
# 4        0.393482        0.685920       -0.304257        1.134053
#
#    Freq_Of_Word_9  Freq_Of_Word_10  ...  Freq_Of_Word_44  Freq_Of_Word_45  \
# 0       -0.318797        -0.352968  ...        -0.120401        -0.323019
# ...

# %%
train.describe()
# Out:
#        Freq_Of_Word_1  Freq_Of_Word_2  Freq_Of_Word_3  Freq_Of_Word_4  \
# count      947.000000      947.000000      947.000000      947.000000
# mean         0.023323        0.039056        0.020516        0.013038
# std          1.104679        1.085628        1.026794        1.345090
# min         -0.351864       -0.318036       -0.561952       -0.039223
# 25%         -0.351864       -0.318036       -0.561952       -0.039223
# 50%         -0.351864       -0.318036       -0.561952       -0.039223
# 75%         -0.351864       -0.318036        0.326735       -0.039223
# max         13.771711       11.065546        9.184940       40.442907
#
#        Freq_Of_Word_5  Freq_Of_Word_6  Freq_Of_Word_7  Freq_Of_Word_8  \
# count      947.000000      947.000000      947.000000      947.000000
# mean        -0.018424        0.002831       -0.006407        0.008428
# std          0.890268        0.970823        0.868676        1.136686
# ...

# %%
test.describe()
# Out:
#        Freq_Of_Word_1  Freq_Of_Word_2  Freq_Of_Word_3  Freq_Of_Word_4  \
# count      527.000000      527.000000      527.000000      527.000000
# mean        -0.034587       -0.015567       -0.011815       -0.034855
# std          0.863755        0.991826        1.008872        0.060872
# min         -0.351864       -0.318036       -0.561952       -0.039223
# 25%         -0.351864       -0.318036       -0.561952       -0.039223
# 50%         -0.351864       -0.318036       -0.561952       -0.039223
# 75%         -0.335593       -0.318036        0.278956       -0.039223
# max          8.662491       12.550362        7.082669        1.059753
#
#        Freq_Of_Word_5  Freq_Of_Word_6  Freq_Of_Word_7  Freq_Of_Word_8  \
# count      527.000000      527.000000      527.000000      527.000000
# mean         0.048186        0.004758       -0.039067       -0.042885
# std          1.224778        1.193867        1.003432        0.636875
# ...

# %%
for i in train.columns:
    plt.figure(figsize=(15,5))
    plt.scatter(range(947),train[i][:947])
    plt.scatter(range(947),train.IsGoodNews[:947])
    plt.title(i)
# Out:
# E:\New folder\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
plt.figure(figsize=(15,5))
plt.scatter(range(527),test['Freq_Of_Word_4'][:527])
plt.scatter(range(527),train['Freq_Of_Word_4'][:527])

# %%
train.IsGoodNews.value_counts()
# Out:
# 0    579
# 1    368
# Name: IsGoodNews, dtype: int64

# %%
label=train.IsGoodNews
train.drop(columns=['IsGoodNews'],inplace=True)

# %%
train.drop(columns=['Freq_Of_Word_4'],inplace=True)
test.drop(columns=['Freq_Of_Word_4'],inplace=True)

# %%
mm=MinMaxScaler()
train=pd.DataFrame(mm.fit_transform(train))
test=pd.DataFrame(mm.fit_transform(test))

# %%
def splitting(m, train= train, label = label, test = test, random_state = 90):
    a = list()
    b = list()
    sss=StratifiedShuffleSplit(random_state= random_state,test_size=0.2,n_splits=5)
    for tr_index, te_index in sss.split(train,label):
        xtrain, xtest = train.loc[tr_index,:], train.loc[te_index,:]
        ytrain, ytest = label[tr_index], label[te_index]   
        m.fit(xtrain,ytrain)
        p = m.predict(xtest)
        a.append(f1_score(ytrain,m.predict(xtrain)))
        b.append(f1_score(ytest,m.predict(xtest)))
  #  print(pd.Series(m.feature_importances_, index = train.columns).sort_values(ascending=True).plot.barh())
    print(np.mean(a),'              ',np.mean(b))
    return((pd.DataFrame(m.predict(test))))

# %%
a=splitting(GradientBoostingClassifier(),train,label,test,random_state=377823)
# Out:
# 0.9810846946454509                0.9045672695779828

# %%
b=splitting(AdaBoostClassifier(),train,label,test,random_state=54473)
# Out:
# 0.9618431699430298                0.8908656165042281

# %%
c=splitting(BaggingClassifier(),train,label,test,random_state=91373)
# Out:
# 0.9894036970016142                0.8825159063917027

# %%
d=splitting(RandomForestClassifier(),train,label,test,random_state=112273)
# Out:
# 0.993156517017636                0.8635921325051761
# E:\New folder\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
e=splitting(DecisionTreeClassifier(),train,label,test,random_state=665623)
# Out:
# 0.9983010502020286                0.8285390357392929

# %%
f=splitting(ExtraTreesClassifier(),train,label,test,random_state=55873)
# Out:
# 0.9986394518471814                0.8899391314555531
# E:\New folder\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
g=splitting(SGDClassifier(),train,label,test,random_state=12563)
# Out:
# 0.8242927999801909                0.8120298527983062
# E:\New folder\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# E:\New folder\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# ...

# %%
sample=pd.read_excel('D:\Machine Learning stuffs\Machinehack-Message-polarity-prediction\MessagePolarity_ParticipantsData\Sample_Submission.xlsx')

# %%
sample.head()
# Out:
#    IsGoodNews
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
a.rename({0:'IsGoodNews'},axis=1,inplace=True)

# %%
a.to_excel('Predicted.xlsx',index=False)

# %%
a.IsGoodNews.value_counts()
# Out:
# 0    325
# 1    202
# Name: IsGoodNews, dtype: int64
